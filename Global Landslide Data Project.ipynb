# %% [markdown]
# Sales Analysis
#
# Import Necessery Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Merging data

# %%
print("Content of the Dataframe: ")
print(df)
# Out:
# Content of the Dataframe:
#               source_name                                        source_link  \
# 0                     AGU  https://blogs.agu.org/landslideblog/2008/10/14...
# 1               Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...
# 2                CBS News  https://www.cbsnews.com/news/dozens-missing-af...
# 3                 Reuters  https://in.reuters.com/article/idINIndia-41450...
# 4             The Freeman  http://www.philstar.com/cebu-news/621414/lands...
# ...                   ...                                                ...
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
# ...

# %%
df = pd.read_csv('https://query.data.world/s/nojfetcc4p27jkiba56lufabf4s2pq')

# %% [markdown]
# ### Cleaning the data

# %%
df = df.drop(columns=['admin_division_population','gazeteer_closest_point','gazeteer_distance','submitted_date','last_edited_date', 'longitude', 'latitude'])

# %%
print("Content of the Dataframe: ")
print(df)
# Out:
# Content of the Dataframe:
#               source_name                                        source_link  \
# 0                     AGU  https://blogs.agu.org/landslideblog/2008/10/14...
# 1               Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...
# 2                CBS News  https://www.cbsnews.com/news/dozens-missing-af...
# 3                 Reuters  https://in.reuters.com/article/idINIndia-41450...
# 4             The Freeman  http://www.philstar.com/cebu-news/621414/lands...
# ...                   ...                                                ...
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
# ...

# %%
df = df.drop_duplicates()
df.sample(7)
# Out:
#                                 source_name  \
# 6969                                   Dawn
# 9492                                   ktvb
# 8953   China Geological Environment InfoNet
# 10844                       Fiji Sun Online
# 2102                                   cctv
# 711                          The Daily Star
# 10725                         The Rio Times
#
#                                              source_link  event_id  \
# 6969   http://www.dawn.com/news/1155032/landslide-kil...      6623
# 9492   http://www.ktvb.com/news/Boise-County-Ccleans-...      3021
# 8953   http://www.cigem.gov.cn/ReadNews.asp?NewsID=12765       296
# 10844  http://fijisun.com.fj/2017/01/04/big-landslide...     10715
# 2102   http://www.cctv.com/english/20080627/103737.shtml       611
# 711    http://www.thedailystar.net/backpage/landslide...      6020
# 10725  http://riotimesonline.com/brazil-news/rio-poli...     10767
#
#                    event_date event_time  \
# ...

# %%
df = df.drop(columns=['country_code', 'event_import_source', 'photo_link', 'notes', 'storm_name', 'location_description', 'event_time', 'event_title'])
df.sample(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df = df.drop(columns=['country_code', 'event_import_source', 'photo_link', 'notes', 'storm_name', 'location_description', 'event_time', 'event_title'])
#       2 df.sample(7)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
print("Content of the Dataframe: ")
print(df)
# Out:
# Content of the Dataframe:
#               source_name                                        source_link  \
# 0                     AGU  https://blogs.agu.org/landslideblog/2008/10/14...
# 1               Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...
# 2                CBS News  https://www.cbsnews.com/news/dozens-missing-af...
# 3                 Reuters  https://in.reuters.com/article/idINIndia-41450...
# 4             The Freeman  http://www.philstar.com/cebu-news/621414/lands...
# ...                   ...                                                ...
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
# ...
